# %%
import pandas as pd
import numpy as np

# %%
# !pip install quandl
import quandl
#yahoo finance - yfinance(s) - библиотека с данными по площадкам
# Out:
# Requirement already satisfied: quandl in c:\users\vadim\appdata\roaming\python\python38\site-packages (3.6.0)
# Requirement already satisfied: python-dateutil in c:\users\vadim\anaconda3\lib\site-packages (from quandl) (2.8.1)
# Requirement already satisfied: six in c:\users\vadim\anaconda3\lib\site-packages (from quandl) (1.15.0)
# Requirement already satisfied: requests>=2.7.0 in c:\users\vadim\anaconda3\lib\site-packages (from quandl) (2.24.0)
# Requirement already satisfied: numpy>=1.8 in c:\users\vadim\anaconda3\lib\site-packages (from quandl) (1.19.2)
# Requirement already satisfied: pandas>=0.14 in c:\users\vadim\anaconda3\lib\site-packages (from quandl) (1.1.3)
# Requirement already satisfied: more-itertools in c:\users\vadim\anaconda3\lib\site-packages (from quandl) (8.6.0)
# Requirement already satisfied: inflection>=0.3.1 in c:\users\vadim\appdata\roaming\python\python38\site-packages (from quandl) (0.5.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\vadim\anaconda3\lib\site-packages (from pandas>=0.14->quandl) (2020.1)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\vadim\anaconda3\lib\site-packages (from requests>=2.7.0->quandl) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\vadim\anaconda3\lib\site-packages (from requests>=2.7.0->quandl) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vadim\anaconda3\lib\site-packages (from requests>=2.7.0->quandl) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\vadim\anaconda3\lib\site-packages (from requests>=2.7.0->quandl) (1.25.11)
# WARNING: You are using pip version 20.3.3; however, version 21.0.1 is available.
# You should consider upgrading via the 'C:\Users\Vadim\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
tickers = ['IEF', 'GLD', 'SPY', 'QQQ']

# %%
# quandl.ApiConfig.api_key = key - для загрузки через quandl

# %%
#data = quandl.get_table('SHARADAR/SFP', ticker= [tickers[0]]) # загрузка IEF

# %%
# data.to_csv(ticker+'.csv') # выгрузка данных в файл с названием

# %%
data = pd.read_csv('IEF.csv')
daily = {}

# %%
path = ['IEF.csv', 'GLD.csv', 'SPY.csv', 'QQQ.csv']

for i, p in enumerate(path):
    data = pd.read_csv(p, index_col = 3)
    data.index = data['date']
    daily[tickers[i]] = data

# %%
daily['SPY']
# Out:
#             None ticker        date     high      low    close       volume  \
# date
# 2021-01-29     0    SPY  2021-01-29  376.670  368.270  370.070  126601429.0
# 2021-01-28     1    SPY  2021-01-28  381.930  375.890  377.630   93773398.0
# 2021-01-27     2    SPY  2021-01-27  380.320  372.010  374.410  122536313.0
# 2021-01-26     3    SPY  2021-01-26  385.850  383.540  383.790   42235069.0
# 2021-01-25     4    SPY  2021-01-25  384.770  378.460  384.390   70171998.0
# ...          ...    ...         ...      ...      ...      ...          ...
# 1998-01-07  5803    SPY  1998-01-07   96.719   95.219   96.469    4424200.0
# 1998-01-06  5804    SPY  1998-01-06   97.281   96.188   96.219    3154900.0
# 1998-01-05  5805    SPY  1998-01-05   98.438   96.781   97.781    4191800.0
# 1998-01-02  5806    SPY  1998-01-02   97.656   96.531   97.563    2360900.0
# 1997-12-31  5807    SPY  1997-12-31   97.625   96.688   97.063    4359500.0
#
#             dividends  closeunadj lastupdated
# date
# 2021-01-29        0.0     370.070  2021-01-29
# 2021-01-28        0.0     377.630  2021-01-28
# 2021-01-27        0.0     374.410  2021-01-27
# 2021-01-26        0.0     383.790  2021-01-26
# 2021-01-25        0.0     384.390  2021-01-25
# ...               ...         ...         ...
# 1998-01-07        0.0      96.469  2020-08-06
# 1998-01-06        0.0      96.219  2020-08-06
# 1998-01-05        0.0      97.781  2020-08-06
# 1998-01-02        0.0      97.563  2020-08-06
# 1997-12-31        0.0      97.063  2020-08-06
#
# [5808 rows x 10 columns]

# %%
for ticker in tickers:
    print(len(daily[ticker])) # длина датафреймов разная
# Out:
# 4659
# 4077
# 5808
# 5510

# %%
daily[tickers[0]]
# Out:
#             None ticker        date    high      low   close     volume  \
# date
# 2021-01-29     0    IEF  2021-01-29  118.79  118.470  118.64  7952081.0
# 2021-01-28     1    IEF  2021-01-28  119.01  118.715  118.85  5394284.0
# 2021-01-27     2    IEF  2021-01-27  119.34  119.120  119.16  5764713.0
# 2021-01-26     3    IEF  2021-01-26  119.06  118.920  119.02  4257174.0
# 2021-01-25     4    IEF  2021-01-25  119.06  118.710  119.06  5688525.0
# ...          ...    ...         ...     ...      ...     ...        ...
# 2002-08-05  4654    IEF  2002-08-05   83.92   83.530   83.92   159300.0
# 2002-08-02  4655    IEF  2002-08-02   83.70   82.900   83.50   120300.0
# 2002-08-01  4656    IEF  2002-08-01   82.90   82.520   82.86    71400.0
# 2002-07-31  4657    IEF  2002-07-31   82.58   82.050   82.52    32600.0
# 2002-07-30  4658    IEF  2002-07-30   82.12   81.700   81.77    41300.0
#
#             dividends  closeunadj lastupdated
# date
# 2021-01-29        0.0      118.64  2021-01-29
# 2021-01-28        0.0      118.85  2021-01-28
# 2021-01-27        0.0      119.16  2021-01-27
# 2021-01-26        0.0      119.02  2021-01-26
# 2021-01-25        0.0      119.06  2021-01-25
# ...               ...         ...         ...
# 2002-08-05        0.0       83.92  2018-06-13
# 2002-08-02        0.0       83.50  2018-06-13
# 2002-08-01        0.0       82.86  2018-06-13
# 2002-07-31        0.0       82.52  2018-06-13
# 2002-07-30        0.0       81.77  2018-06-13
#
# [4659 rows x 10 columns]

# %%
def data_cutting(data, tickers, tables_len):
    min_len = min(tables_len)
    for ticker in tickers:
        data[ticker] = data[ticker].iloc[:min_len,:]
        data[ticker] = data[ticker][::-1][1:]

def tickers_download(tickers, dictionary):
    tables_len = []
    for i, p in enumerate(path):
        data = pd.read_csv(p) # временный таймфрейм
        data.drop('None', axis = 1, inplace = True)
        data.index = pd.to_datetime(data['date']) #важно писать так, через pd.to_datetime, иначе читается как строка, а не DTTM
        daily[tickers[i]] = data
    
        data['pct_change'] = data[::-1]['close'].pct_change()
        length = len(data)
        tables_len.append(length)
    
    data_cutting(daily, tickers, tables_len)

# %%
tickers_download(tickers, daily)

# %%
daily[tickers[1]]
# Out:
#            ticker        date    open     high     low   close      volume  \
# date
# 2004-11-19    GLD  2004-11-19   44.49   44.920   44.47   44.78  11655300.0
# 2004-11-22    GLD  2004-11-22   44.75   44.970   44.74   44.95  11996000.0
# 2004-11-23    GLD  2004-11-23   44.88   44.920   44.72   44.75   3169200.0
# 2004-11-24    GLD  2004-11-24   44.93   45.050   44.79   45.05   6105100.0
# 2004-11-26    GLD  2004-11-26   45.25   45.600   45.06   45.29   3097700.0
# ...           ...         ...     ...      ...     ...     ...         ...
# 2021-01-25    GLD  2021-01-25  174.82  174.960  173.19  174.05   5934060.0
# 2021-01-26    GLD  2021-01-26  173.98  174.260  173.42  173.62   4671622.0
# 2021-01-27    GLD  2021-01-27  172.93  173.520  171.66  172.52   9027504.0
# 2021-01-28    GLD  2021-01-28  174.28  174.730  172.04  172.68   9381003.0
# 2021-01-29    GLD  2021-01-29  174.87  175.163  172.61  172.61  11250790.0
#
#             dividends  closeunadj lastupdated  pct_change
# date
# 2004-11-19        0.0       44.78  2018-06-13    0.009013
# 2004-11-22        0.0       44.95  2018-06-13    0.003796
# 2004-11-23        0.0       44.75  2018-06-13   -0.004449
# 2004-11-24        0.0       45.05  2018-06-13    0.006704
# 2004-11-26        0.0       45.29  2018-06-13    0.005327
# ...               ...         ...         ...         ...
# 2021-01-25        0.0      174.05  2021-01-25    0.000863
# 2021-01-26        0.0      173.62  2021-01-26   -0.002471
# 2021-01-27        0.0      172.52  2021-01-27   -0.006336
# 2021-01-28        0.0      172.68  2021-01-28    0.000927
# 2021-01-29        0.0      172.61  2021-01-29   -0.000405
#
# [4076 rows x 11 columns]

# %%
df = daily[tickers[0]]

df.resample('M').mean() # группировка данных
# Out:
#                   open        high         low       close        volume  \
# date
# 2004-11-30   85.117143   85.242857   84.970000   85.072857  4.665857e+05
# 2004-12-31   85.209545   85.355000   85.052727   85.208727  2.747727e+05
# 2005-01-31   85.156500   85.304000   85.025800   85.201000  3.027700e+05
# 2005-02-28   85.373684   85.505789   85.210000   85.338947  1.993684e+05
# 2005-03-31   83.515909   83.649091   83.355000   83.480455  2.931591e+05
# ...                ...         ...         ...         ...           ...
# 2020-09-30  121.892857  122.013905  121.753476  121.882143  3.909494e+06
# 2020-10-31  121.028182  121.155864  120.853864  120.968864  5.637958e+06
# 2020-11-30  120.156250  120.266900  120.037800  120.162500  6.714010e+06
# 2020-12-31  119.754909  119.886545  119.626864  119.775455  4.031606e+06
# 2021-01-31  118.652789  118.806526  118.515579  118.698947  6.151205e+06
#
#             dividends  closeunadj  pct_change
# date
# 2004-11-30   0.000000   85.072857   -0.002125
# 2004-12-31   0.024227   85.208727    0.000248
# 2005-01-31   0.000000   85.201000    0.000437
# 2005-02-28   0.013737   85.338947   -0.000880
# 2005-03-31   0.010500   83.480455   -0.000302
# ...               ...         ...         ...
# 2020-09-30   0.004190  121.882143    0.000123
# 2020-10-31   0.003591  120.968864   -0.000659
# 2020-11-30   0.003800  120.162500    0.000143
# 2020-12-31   0.006955  119.775455   -0.000164
# 2021-01-31   0.000000  118.698947   -0.000575
#
# [195 rows x 8 columns]

# %%
df.resample('M').mean()
# Out:
#                   open        high         low       close        volume  \
# date
# 2004-11-30   85.117143   85.242857   84.970000   85.072857  4.665857e+05
# 2004-12-31   85.209545   85.355000   85.052727   85.208727  2.747727e+05
# 2005-01-31   85.156500   85.304000   85.025800   85.201000  3.027700e+05
# 2005-02-28   85.373684   85.505789   85.210000   85.338947  1.993684e+05
# 2005-03-31   83.515909   83.649091   83.355000   83.480455  2.931591e+05
# ...                ...         ...         ...         ...           ...
# 2020-09-30  121.892857  122.013905  121.753476  121.882143  3.909494e+06
# 2020-10-31  121.028182  121.155864  120.853864  120.968864  5.637958e+06
# 2020-11-30  120.156250  120.266900  120.037800  120.162500  6.714010e+06
# 2020-12-31  119.754909  119.886545  119.626864  119.775455  4.031606e+06
# 2021-01-31  118.652789  118.806526  118.515579  118.698947  6.151205e+06
#
#             dividends  closeunadj  pct_change
# date
# 2004-11-30   0.000000   85.072857   -0.002125
# 2004-12-31   0.024227   85.208727    0.000248
# 2005-01-31   0.000000   85.201000    0.000437
# 2005-02-28   0.013737   85.338947   -0.000880
# 2005-03-31   0.010500   83.480455   -0.000302
# ...               ...         ...         ...
# 2020-09-30   0.004190  121.882143    0.000123
# 2020-10-31   0.003591  120.968864   -0.000659
# 2020-11-30   0.003800  120.162500    0.000143
# 2020-12-31   0.006955  119.775455   -0.000164
# 2021-01-31   0.000000  118.698947   -0.000575
#
# [195 rows x 8 columns]

# %%
df.resample('M').mean()['close'].plot() # группировка данных
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df
# Out:
#            ticker        date     open    high      low   close     volume  \
# date
# 2004-11-19    IEF  2004-11-19   85.700   85.75   85.160   85.30  2162100.0
# 2004-11-22    IEF  2004-11-22   85.250   85.43   85.240   85.36   168100.0
# 2004-11-23    IEF  2004-11-23   85.270   85.59   85.210   85.28   183600.0
# 2004-11-24    IEF  2004-11-24   85.340   85.40   85.250   85.40    51900.0
# 2004-11-26    IEF  2004-11-26   85.050   85.13   85.020   85.09    62600.0
# ...           ...         ...      ...     ...      ...     ...        ...
# 2021-01-25    IEF  2021-01-25  118.750  119.06  118.710  119.06  5688525.0
# 2021-01-26    IEF  2021-01-26  118.940  119.06  118.920  119.02  4257174.0
# 2021-01-27    IEF  2021-01-27  119.220  119.34  119.120  119.16  5764713.0
# 2021-01-28    IEF  2021-01-28  119.000  119.01  118.715  118.85  5394284.0
# 2021-01-29    IEF  2021-01-29  118.505  118.79  118.470  118.64  7952081.0
#
#             dividends  closeunadj lastupdated  pct_change
# date
# 2004-11-19        0.0       85.30  2018-06-13   -0.005480
# 2004-11-22        0.0       85.36  2018-06-13    0.000703
# 2004-11-23        0.0       85.28  2018-06-13   -0.000937
# 2004-11-24        0.0       85.40  2018-06-13    0.001407
# 2004-11-26        0.0       85.09  2018-06-13   -0.003630
# ...               ...         ...         ...         ...
# 2021-01-25        0.0      119.06  2021-01-25    0.004048
# 2021-01-26        0.0      119.02  2021-01-26   -0.000336
# 2021-01-27        0.0      119.16  2021-01-27    0.001176
# 2021-01-28        0.0      118.85  2021-01-28   -0.002602
# 2021-01-29        0.0      118.64  2021-01-29   -0.001767
#
# [4076 rows x 11 columns]

# %%
df['close'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
length = len(daily[tickers[0]]) # у всех одинаковая
best_tickers = []

for i in range(length):
    temp_list = []
    for ticker in tickers:
        change = daily[ticker]['pct_change'][i]
        temp_list.append(change)
    max_change = min(temp_list)
    ident = temp_list.index(max_change)
    best_ticker = tickers[ident]
    best_tickers.append(best_ticker)

# %%
a = [1.1 , 0.99, 0.98]
a = np.array(a)
a.cumprod()
#min_a = min(a)
#min_a
#a.index(min_a)
# Out:
# array([1.1    , 1.089  , 1.06722])

# %%
best_tickers[:10]
# Out:
# ['QQQ', 'IEF', 'GLD', 'IEF', 'IEF', 'IEF', 'GLD', 'IEF', 'GLD', 'SPY']

# %%
money = 1
strategy_values = [] # изменение депозита с каждой сделкой

for i in range(1, length, 30):
    ticker = best_tickers[i-1]
    change = (daily[ticker]['pct_change'][i : i+30] + 1).cumprod()[-1]
    money = money * change
    strategy_values.append(money)

# %%
best_tickers
# Out:
# ['QQQ',
#  'IEF',
#  'GLD',
#  'IEF',
#  'IEF',
#  'IEF',
#  'GLD',
#  'IEF',
#  'GLD',
#  'SPY',
#  'GLD',
#  'QQQ',
#  'GLD',
#  'GLD',
#  'GLD',
#  'IEF',
#  'GLD',
#  'QQQ',
#  'QQQ',
#  'QQQ',
#  'QQQ',
#  'GLD',
#  'GLD',
#  'IEF',
#  'IEF',
#  'GLD',
#  'GLD',
#  'SPY',
#  'SPY',
#  'GLD',
#  'QQQ',
#  'SPY',
#  'GLD',
#  'GLD',
#  'QQQ',
#  'QQQ',
#  'IEF',
#  'QQQ',
#  'GLD',
#  'IEF',
#  'QQQ',
#  'QQQ',
#  'QQQ',
#  'QQQ',
#  'GLD',
#  'IEF',
#  'GLD',
#  'QQQ',
#  'GLD',
#  'IEF',
#  'IEF',
#  'GLD',
#  'GLD',
#  'GLD',
#  'GLD',
#  'QQQ',
#  'IEF',
#  'IEF',
#  'SPY',
#  'IEF',
#  'QQQ',
#  'QQQ',
#  'IEF',
#  'SPY',
#  'GLD',
#  'GLD',
#  'IEF',
#  'QQQ',
#  'GLD',
#  'QQQ',
#  'QQQ',
#  'IEF',
#  'IEF',
#  'QQQ',
#  'SPY',
#  'QQQ',
#  'QQQ',
#  'GLD',
#  'SPY',
#  'QQQ',
#  'GLD',
#  'SPY',
#  'GLD',
#  'QQQ',
#  'GLD',
#  'GLD',
#  'IEF',
#  'QQQ',
#  'GLD',
#  'QQQ',
#  'QQQ',
#  'GLD',
#  'IEF',
#  'QQQ',
#  'IEF',
#  'SPY',
#  'QQQ',
#  'GLD',
#  'QQQ',
#  'QQQ',
#  'QQQ',
#  'IEF',
#  'IEF',
#  'SPY',
#  'IEF',
#  'QQQ',
#  'IEF',
#  'SPY',
#  'GLD',
#  'SPY',
#  'IEF',
#  'GLD',
#  'GLD',
#  'IEF',
#  'SPY',
#  'GLD',
#  'IEF',
#  'SPY',
#  'GLD',
#  'GLD',
#  'GLD',
#  'GLD',
#  'GLD',
#  'IEF',
#  'IEF',
#  'GLD',
#  'GLD',
#  'SPY',
#  'QQQ',
#  'GLD',
#  'QQQ',
#  'SPY',
#  'GLD',
#  'IEF',
#  'QQQ',
#  'SPY',
#  'QQQ',
#  'QQQ',
#  'GLD',
#  'QQQ',
#  'IEF',
#  'GLD',
#  'IEF',
#  'SPY',
#  'IEF',
#  'IEF',
#  'QQQ',
#  'GLD',
#  'SPY',
#  'QQQ',
#  'QQQ',
#  'GLD',
#  'SPY',
#  'QQQ',
#  'GLD',
#  'GLD',
#  'SPY',
#  'IEF',
#  'IEF',
#  'IEF',
#  'IEF',
#  'GLD',
#  'GLD',
#  'SPY',
#  'QQQ',
#  'GLD',
#  'IEF',
#  'IEF',
#  'QQQ',
#  'QQQ',
#  'GLD',
#  'IEF',
#  'IEF',
#  'QQQ',
#  'IEF',
#  'IEF',
#  'QQQ',
#  'QQQ',
#  'SPY',
#  'QQQ',
#  'GLD',
#  'QQQ',
#  'SPY',
#  'SPY',
#  'GLD',
#  'QQQ',
#  'GLD',
#  'QQQ',
#  'GLD',
#  'SPY',
#  'QQQ',
#  'SPY',
#  'IEF',
#  'SPY',
#  'GLD',
#  'GLD',
#  'IEF',
#  'IEF',
#  'QQQ',
#  'IEF',
#  'IEF',
#  'SPY',
#  'IEF',
#  'IEF',
#  'GLD',
#  'QQQ',
#  'IEF',
#  'IEF',
#  'QQQ',
#  'SPY',
#  'QQQ',
#  'GLD',
#  'IEF',
#  'IEF',
#  'GLD',
#  'QQQ',
#  'IEF',
#  'GLD',
#  'IEF',
#  'SPY',
#  'QQQ',
#  'QQQ',
#  'IEF',
#  'SPY',
#  'QQQ',
#  'QQQ',
#  'IEF',
#  'GLD',
#  'IEF',
#  'SPY',
#  'GLD',
#  'SPY',
#  'SPY',
#  'IEF',
#  'IEF',
#  'QQQ',
#  'QQQ',
#  'IEF',
#  'GLD',
#  'GLD',
#  'IEF',
#  'GLD',
#  'GLD',
#  'SPY',
#  'SPY',
#  'IEF',
#  'GLD',
#  'IEF',
#  'IEF',
#  'QQQ',
#  'SPY',
#  'IEF',
#  'IEF',
#  'IEF',
#  'IEF',
#  'GLD',
#  'SPY',
#  'QQQ',
#  'IEF',
#  'GLD',
#  'IEF',
#  'IEF',
#  'QQQ',
#  'SPY',
#  'SPY',
#  'QQQ',
#  'IEF',
#  'IEF',
#  'GLD',
#  'GLD',
#  'SPY',
#  'QQQ',
#  'QQQ',
#  'GLD',
#  'IEF',
#  'IEF',
#  'GLD',
#  'SPY',
#  'IEF',
#  'QQQ',
#  'QQQ',
#  'IEF',
#  'IEF',
#  'GLD',
#  'IEF',
#  'IEF',
#  'GLD',
#  'IEF',
#  'QQQ',
#  'SPY',
#  'QQQ',
#  'GLD',
#  'IEF',
#  'QQQ',
#  'IEF',
#  'IEF',
#  'IEF',
#  'GLD',
#  'GLD',
#  'IEF',
#  'SPY',
#  'IEF',
#  'QQQ',
#  'QQQ',
#  'QQQ',
#  'GLD',
#  'IEF',
#  'QQQ',
#  'GLD',
#  'GLD',
#  'IEF',
#  'GLD',
#  'IEF',
#  'QQQ',
#  'QQQ',
#  'IEF',
#  'GLD',
#  'IEF',
#  'GLD',
#  'QQQ',
#  'IEF',
#  'IEF',
#  'GLD',
#  'GLD',
#  'QQQ',
#  'GLD',
#  'QQQ',
#  'GLD',
#  'IEF',
#  'IEF',
#  'IEF',
#  'QQQ',
#  'GLD',
#  'SPY',
#  'QQQ',
#  'GLD',
#  'QQQ',
#  'SPY',
#  'IEF',
#  'SPY',
#  'IEF',
#  'IEF',
#  'GLD',
#  'IEF',
#  'GLD',
#  'IEF',
#  'IEF',
#  'GLD',
#  'QQQ',
#  'GLD',
#  'IEF',
#  'IEF',
#  'QQQ',
#  'IEF',
#  'IEF',
#  'GLD',
#  'QQQ',
#  'GLD',
#  'IEF',
#  'IEF',
#  'GLD',
#  'QQQ',
#  'QQQ',
#  'IEF',
#  'SPY',
#  'IEF',
#  'IEF',
#  'GLD',
#  'QQQ',
#  'QQQ',
#  'QQQ',
#  'QQQ',
#  'GLD',
#  'QQQ',
#  'SPY',
#  'GLD',
#  'GLD',
#  'QQQ',
#  'QQQ',
#  'GLD',
#  'IEF',
#  'IEF',
#  'QQQ',
#  'GLD',
#  'GLD',
#  'QQQ',
#  'QQQ',
#  'GLD',
#  'SPY',
#  'GLD',
#  'GLD',
#  'QQQ',
#  'GLD',
#  'IEF',
#  'IEF',
#  'SPY',
#  'GLD',
#  'IEF',
#  'IEF',
#  'QQQ',
#  'QQQ',
#  'IEF',
#  'QQQ',
#  'IEF',
#  'IEF',
#  'QQQ',
#  'IEF',
#  'QQQ',
#  'QQQ',
#  'QQQ',
#  'GLD',
#  'IEF',
#  'QQQ',
#  'QQQ',
#  'QQQ',
#  'GLD',
#  'GLD',
#  'IEF',
#  'GLD',
#  'GLD',
#  'GLD',
#  'IEF',
#  'QQQ',
#  'QQQ',
#  'IEF',
#  'SPY',
#  'QQQ',
#  'IEF',
#  'GLD',
#  'QQQ',
#  'QQQ',
#  'GLD',
#  'SPY',
#  'GLD',
#  'GLD',
#  'GLD',
#  'GLD',
#  'IEF',
#  'GLD',
#  'GLD',
#  'QQQ',
#  'GLD',
#  'QQQ',
#  'GLD',
#  'GLD',
#  'GLD',
#  'GLD',
#  'SPY',
#  'QQQ',
#  'GLD',
#  'IEF',
#  'QQQ',
#  'GLD',
#  'GLD',
#  'GLD',
#  'GLD',
#  'IEF',
#  'GLD',
#  'SPY',
#  'IEF',
#  'GLD',
#  'IEF',
#  'QQQ',
#  'QQQ',
#  'GLD',
#  'IEF',
#  'QQQ',
#  'IEF',
#  'GLD',
#  'QQQ',
#  'GLD',
#  'GLD',
#  'IEF',
#  'IEF',
#  'SPY',
#  'IEF',
#  'GLD',
#  'IEF',
#  'IEF',
#  'QQQ',
#  'QQQ',
#  'QQQ',
#  'IEF',
#  'GLD',
#  'GLD',
#  'QQQ',
#  'SPY',
#  'SPY',
#  'QQQ',
#  'SPY',
#  'SPY',
#  'QQQ',
#  'IEF',
#  'IEF',
#  'GLD',
#  'GLD',
#  'GLD',
#  'QQQ',
#  'GLD',
#  'GLD',
#  'GLD',
#  'IEF',
#  'GLD',
#  'QQQ',
#  'GLD',
#  'SPY',
#  'IEF',
#  'SPY',
#  'QQQ',
#  'GLD',
#  'GLD',
#  'QQQ',
#  'QQQ',
#  'IEF',
#  'GLD',
#  'GLD',
#  'QQQ',
#  'GLD',
#  'SPY',
#  'QQQ',
#  'IEF',
#  'GLD',
#  'GLD',
#  'QQQ',
#  'QQQ',
#  'QQQ',
#  'QQQ',
#  'QQQ',
#  'IEF',
#  'IEF',
#  'QQQ',
#  'SPY',
#  'GLD',
#  'GLD',
#  'GLD',
#  'QQQ',
#  'SPY',
#  'GLD',
#  'IEF',
#  'IEF',
#  'GLD',
#  'QQQ',
#  'QQQ',
#  'IEF',
#  'QQQ',
#  'IEF',
#  'IEF',
#  'QQQ',
#  'QQQ',
#  'GLD',
#  'QQQ',
#  'IEF',
#  'QQQ',
#  'GLD',
#  'QQQ',
#  'QQQ',
#  'GLD',
#  'SPY',
#  'QQQ',
#  'GLD',
#  'IEF',
#  'IEF',
#  'GLD',
#  'QQQ',
#  'GLD',
#  'SPY',
#  'IEF',
#  'SPY',
#  'QQQ',
#  'QQQ',
#  'IEF',
#  'GLD',
#  'GLD',
#  'GLD',
#  'IEF',
#  'QQQ',
#  'IEF',
#  'IEF',
#  'SPY',
#  'QQQ',
#  'IEF',
#  'QQQ',
#  'SPY',
#  'IEF',
#  'IEF',
#  'IEF',
#  'QQQ',
#  'GLD',
#  'SPY',
#  'QQQ',
#  'QQQ',
#  'GLD',
#  'IEF',
#  'IEF',
#  'IEF',
#  'SPY',
#  'IEF',
#  'GLD',
#  'SPY',
#  'QQQ',
#  'GLD',
#  'IEF',
#  'IEF',
#  'GLD',
#  'QQQ',
#  'GLD',
#  'IEF',
#  'GLD',
#  'GLD',
#  'IEF',
#  'GLD',
#  'SPY',
#  'QQQ',
#  'GLD',
#  'IEF',
#  'IEF',
#  'QQQ',
#  'QQQ',
#  'GLD',
#  'GLD',
#  'GLD',
#  'IEF',
#  'QQQ',
#  'QQQ',
#  'GLD',
#  'GLD',
#  'IEF',
#  'SPY',
#  'GLD',
#  'QQQ',
#  'QQQ',
#  'IEF',
#  'IEF',
#  'GLD',
#  'SPY',
#  'IEF',
#  'SPY',
#  'SPY',
#  'SPY',
#  'SPY',
#  'GLD',
#  'IEF',
#  'SPY',
#  'IEF',
#  'IEF',
#  'SPY',
#  'SPY',
#  'QQQ',
#  'SPY',
#  'GLD',
#  'QQQ',
#  'GLD',
#  'GLD',
#  'IEF',
#  'IEF',
#  'GLD',
#  'IEF',
#  'GLD',
#  'IEF',
#  'IEF',
#  'QQQ',
#  'SPY',
#  'IEF',
#  'IEF',
#  'GLD',
#  'GLD',
#  'IEF',
#  'SPY',
#  'IEF',
#  'SPY',
#  'GLD',
#  'SPY',
#  'GLD',
#  'SPY',
#  'QQQ',
#  'IEF',
#  'QQQ',
#  'IEF',
#  'GLD',
#  'SPY',
#  'IEF',
#  'GLD',
#  'IEF',
#  'SPY',
#  'QQQ',
#  'GLD',
#  'QQQ',
#  'QQQ',
#  'GLD',
#  'IEF',
#  'SPY',
#  'GLD',
#  'IEF',
#  'QQQ',
#  'IEF',
#  'SPY',
#  'QQQ',
#  'IEF',
#  'GLD',
#  'IEF',
#  'IEF',
#  'QQQ',
#  'IEF',
#  'QQQ',
#  'SPY',
#  'IEF',
#  'IEF',
#  'IEF',
#  'GLD',
#  'QQQ',
#  'IEF',
#  'GLD',
#  'IEF',
#  'GLD',
#  'SPY',
#  'SPY',
#  'GLD',
#  'IEF',
#  'SPY',
#  'IEF',
#  'GLD',
#  'QQQ',
#  'SPY',
#  'IEF',
#  'GLD',
#  'IEF',
#  'SPY',
#  'QQQ',
#  'IEF',
#  'SPY',
#  'SPY',
#  'GLD',
#  'SPY',
#  'SPY',
#  'GLD',
#  'IEF',
#  'QQQ',
#  'QQQ',
#  'IEF',
#  'IEF',
#  'GLD',
#  'IEF',
#  'SPY',
#  'SPY',
#  'SPY',
#  'IEF',
#  'SPY',
#  'QQQ',
#  'QQQ',
#  'GLD',
#  'IEF',
#  'QQQ',
#  'GLD',
#  'GLD',
#  'SPY',
#  'IEF',
#  'SPY',
#  'IEF',
#  'SPY',
#  'GLD',
#  'GLD',
#  'GLD',
#  'GLD',
#  'QQQ',
#  'SPY',
#  'GLD',
#  'IEF',
#  'GLD',
#  'IEF',
#  'SPY',
#  'IEF',
#  'GLD',
#  'SPY',
#  'QQQ',
#  'IEF',
#  'QQQ',
#  'GLD',
#  'IEF',
#  'IEF',
#  'IEF',
#  'SPY',
#  'SPY',
#  'QQQ',
#  'QQQ',
#  'SPY',
#  'QQQ',
#  'QQQ',
#  'QQQ',
#  'GLD',
#  'IEF',
#  'QQQ',
#  'IEF',
#  'QQQ',
#  'GLD',
#  'SPY',
#  'SPY',
#  'QQQ',
#  'IEF',
#  'IEF',
#  'QQQ',
#  'IEF',
#  'GLD',
#  'SPY',
#  'GLD',
#  'GLD',
#  'QQQ',
#  'QQQ',
#  'QQQ',
#  'IEF',
#  'SPY',
#  'IEF',
#  'GLD',
#  'IEF',
#  'QQQ',
#  'GLD',
#  'IEF',
#  'IEF',
#  'QQQ',
#  'IEF',
#  'GLD',
#  'IEF',
#  'SPY',
#  'SPY',
#  'QQQ',
#  'QQQ',
#  'GLD',
#  'IEF',
#  'QQQ',
#  'SPY',
#  'QQQ',
#  'IEF',
#  'SPY',
#  'IEF',
#  'QQQ',
#  'QQQ',
#  'GLD',
#  'GLD',
#  'GLD',
#  'IEF',
#  'SPY',
#  'SPY',
#  'QQQ',
#  'GLD',
#  'GLD',
#  'GLD',
#  'IEF',
#  'IEF',
#  'SPY',
#  'IEF',
#  'GLD',
#  'QQQ',
#  'GLD',
#  'QQQ',
#  'QQQ',
#  'IEF',
#  'IEF',
#  'GLD',
#  'GLD',
#  'GLD',
#  'QQQ',
#  'GLD',
#  'GLD',
#  'QQQ',
#  'SPY',
#  'GLD',
#  'QQQ',
#  'GLD',
#  'IEF',
#  'SPY',
#  'IEF',
#  'QQQ',
#  'SPY',
#  'QQQ',
#  'GLD',
#  'GLD',
#  'QQQ',
#  'IEF',
#  'IEF',
#  'QQQ',
#  'SPY',
#  'QQQ',
#  'GLD',
#  'SPY',
#  'GLD',
#  'IEF',
#  'GLD',
#  'SPY',
#  'QQQ',
#  'GLD',
#  'IEF',
#  'IEF',
#  'SPY',
#  'GLD',
#  'GLD',
#  'QQQ',
#  'GLD',
#  'IEF',
#  'IEF',
#  'QQQ',
#  'QQQ',
#  'IEF',
#  'QQQ',
#  'GLD',
#  'QQQ',
#  'GLD',
#  'QQQ',
#  'SPY',
#  'QQQ',
#  'IEF',
#  'QQQ',
#  'GLD',
#  'SPY',
#  'GLD',
#  'QQQ',
#  'IEF',
#  'QQQ',
#  'SPY',
#  'SPY',
#  'GLD',
#  'IEF',
#  'QQQ',
#  'SPY',
#  'GLD',
#  'GLD',
#  'SPY',
#  'IEF',
#  'QQQ',
#  'GLD',
#  'GLD',
#  'SPY',
#  'QQQ',
#  'GLD',
#  'GLD',
#  'IEF',
#  'SPY',
#  'GLD',
#  'GLD',
#  'SPY',
#  'SPY',
#  'GLD',
#  'GLD',
#  'SPY',
#  'QQQ',
#  'GLD',
#  'QQQ',
#  'GLD',
#  'QQQ',
#  'QQQ',
#  'IEF',
#  'IEF',
#  'QQQ',
#  'GLD',
#  'QQQ',
#  'QQQ',
#  'QQQ',
#  'QQQ',
#  'GLD',
#  'GLD',
#  'GLD',
#  'IEF',
#  'SPY',
#  'GLD',
#  'QQQ',
#  'GLD',
#  'IEF',
#  'QQQ',
#  'SPY',
#  'GLD',
#  'IEF',
#  'QQQ',
#  'QQQ',
#  'GLD',
#  'QQQ',
#  'QQQ',
#  'QQQ',
#  'SPY',
#  'QQQ',
#  'SPY',
#  'SPY',
#  'GLD',
#  'GLD',
#  'QQQ',
#  'SPY',
#  'GLD',
#  'GLD',
#  'IEF',
#  'QQQ',
#  'GLD',
#  'GLD',
#  'SPY',
#  'SPY',
#  'IEF',
#  'SPY',
#  'GLD',
#  'GLD',
#  'GLD',
#  'IEF',
#  'QQQ',
#  'SPY',
#  'IEF',
#  ...]

# %%
s = pd.DataFrame(strategy_values)
s.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### ДЗ
#
# - yfinance библиотека
# - построить свечные графики с помощью plotly на любые акции
# - прописать свою стратегию торговли (как выбирать лучший тикер и сколько его держать)
